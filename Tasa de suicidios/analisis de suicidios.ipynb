# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
dfdata = pd.read_csv('master.csv', encoding=('utf-8'))

# %%
dfdata.shape
# Out:
# (27820, 12)

# %%
dfdata.head(50)
# Out:
#     country  year     sex          age  suicides_no  population  \
# 0   Albania  1987    male  15-24 years           21      312900
# 1   Albania  1987    male  35-54 years           16      308000
# 2   Albania  1987  female  15-24 years           14      289700
# 3   Albania  1987    male    75+ years            1       21800
# 4   Albania  1987    male  25-34 years            9      274300
# 5   Albania  1987  female    75+ years            1       35600
# 6   Albania  1987  female  35-54 years            6      278800
# 7   Albania  1987  female  25-34 years            4      257200
# 8   Albania  1987    male  55-74 years            1      137500
# 9   Albania  1987  female   5-14 years            0      311000
# 10  Albania  1987  female  55-74 years            0      144600
# 11  Albania  1987    male   5-14 years            0      338200
# 12  Albania  1988  female    75+ years            2       36400
# 13  Albania  1988    male  15-24 years           17      319200
# 14  Albania  1988    male    75+ years            1       22300
# 15  Albania  1988    male  35-54 years           14      314100
# 16  Albania  1988    male  55-74 years            4      140200
# 17  Albania  1988  female  15-24 years            8      295600
# 18  Albania  1988  female  55-74 years            3      147500
# 19  Albania  1988  female  25-34 years            5      262400
# 20  Albania  1988    male  25-34 years            5      279900
# 21  Albania  1988  female  35-54 years            4      284500
# 22  Albania  1988  female   5-14 years            0      317200
# 23  Albania  1988    male   5-14 years            0      345000
# 24  Albania  1989    male    75+ years            2       22500
# 25  Albania  1989    male  25-34 years           18      283600
# 26  Albania  1989    male  35-54 years           15      318400
# 27  Albania  1989    male  55-74 years            6      142100
# 28  Albania  1989    male  15-24 years           12      323500
# 29  Albania  1989  female  35-54 years            7      288600
# 30  Albania  1989  female  15-24 years            5      299900
# 31  Albania  1989  female  25-34 years            2      266300
# 32  Albania  1989  female  55-74 years            1      149600
# 33  Albania  1989  female   5-14 years            0      321900
# 34  Albania  1989  female    75+ years            0       37000
# 35  Albania  1989    male   5-14 years            0      349700
# 36  Albania  1992    male  35-54 years           12      343800
# 37  Albania  1992    male  15-24 years            9      263700
# 38  Albania  1992    male  55-74 years            5      159500
# 39  Albania  1992    male  25-34 years            7      245500
# 40  Albania  1992  female  15-24 years            7      292400
# 41  Albania  1992  female  25-34 years            4      267400
# 42  Albania  1992  female  35-54 years            2      323100
# 43  Albania  1992  female  55-74 years            1      164900
# 44  Albania  1992  female   5-14 years            0      336700
# 45  Albania  1992  female    75+ years            0       38700
# 46  Albania  1992    male   5-14 years            0      362900
# 47  Albania  1992    male    75+ years            0       23900
# 48  Albania  1993    male  15-24 years           18      243300
# 49  Albania  1993    male  55-74 years            7      165000
#
#     suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0                6.71  Albania1987           NaN      2,156,624,900
# 1                5.19  Albania1987           NaN      2,156,624,900
# 2                4.83  Albania1987           NaN      2,156,624,900
# 3                4.59  Albania1987           NaN      2,156,624,900
# 4                3.28  Albania1987           NaN      2,156,624,900
# 5                2.81  Albania1987           NaN      2,156,624,900
# 6                2.15  Albania1987           NaN      2,156,624,900
# 7                1.56  Albania1987           NaN      2,156,624,900
# 8                0.73  Albania1987           NaN      2,156,624,900
# 9                0.00  Albania1987           NaN      2,156,624,900
# 10               0.00  Albania1987           NaN      2,156,624,900
# 11               0.00  Albania1987           NaN      2,156,624,900
# 12               5.49  Albania1988           NaN      2,126,000,000
# 13               5.33  Albania1988           NaN      2,126,000,000
# 14               4.48  Albania1988           NaN      2,126,000,000
# 15               4.46  Albania1988           NaN      2,126,000,000
# 16               2.85  Albania1988           NaN      2,126,000,000
# 17               2.71  Albania1988           NaN      2,126,000,000
# 18               2.03  Albania1988           NaN      2,126,000,000
# 19               1.91  Albania1988           NaN      2,126,000,000
# 20               1.79  Albania1988           NaN      2,126,000,000
# 21               1.41  Albania1988           NaN      2,126,000,000
# 22               0.00  Albania1988           NaN      2,126,000,000
# 23               0.00  Albania1988           NaN      2,126,000,000
# 24               8.89  Albania1989           NaN      2,335,124,988
# 25               6.35  Albania1989           NaN      2,335,124,988
# 26               4.71  Albania1989           NaN      2,335,124,988
# 27               4.22  Albania1989           NaN      2,335,124,988
# 28               3.71  Albania1989           NaN      2,335,124,988
# 29               2.43  Albania1989           NaN      2,335,124,988
# 30               1.67  Albania1989           NaN      2,335,124,988
# 31               0.75  Albania1989           NaN      2,335,124,988
# 32               0.67  Albania1989           NaN      2,335,124,988
# 33               0.00  Albania1989           NaN      2,335,124,988
# 34               0.00  Albania1989           NaN      2,335,124,988
# 35               0.00  Albania1989           NaN      2,335,124,988
# 36               3.49  Albania1992           NaN        709,452,584
# 37               3.41  Albania1992           NaN        709,452,584
# 38               3.13  Albania1992           NaN        709,452,584
# 39               2.85  Albania1992           NaN        709,452,584
# 40               2.39  Albania1992           NaN        709,452,584
# 41               1.50  Albania1992           NaN        709,452,584
# 42               0.62  Albania1992           NaN        709,452,584
# 43               0.61  Albania1992           NaN        709,452,584
# 44               0.00  Albania1992           NaN        709,452,584
# 45               0.00  Albania1992           NaN        709,452,584
# 46               0.00  Albania1992           NaN        709,452,584
# 47               0.00  Albania1992           NaN        709,452,584
# 48               7.40  Albania1993           NaN      1,228,071,038
# 49               4.24  Albania1993           NaN      1,228,071,038
#
#     gdp_per_capita ($)       generation
# 0                  796     Generation X
# 1                  796           Silent
# 2                  796     Generation X
# 3                  796  G.I. Generation
# 4                  796          Boomers
# 5                  796  G.I. Generation
# 6                  796           Silent
# 7                  796          Boomers
# 8                  796  G.I. Generation
# 9                  796     Generation X
# 10                 796  G.I. Generation
# 11                 796     Generation X
# 12                 769  G.I. Generation
# 13                 769     Generation X
# 14                 769  G.I. Generation
# 15                 769           Silent
# 16                 769  G.I. Generation
# 17                 769     Generation X
# 18                 769  G.I. Generation
# 19                 769          Boomers
# 20                 769          Boomers
# 21                 769           Silent
# 22                 769     Generation X
# 23                 769     Generation X
# 24                 833  G.I. Generation
# 25                 833          Boomers
# 26                 833           Silent
# 27                 833  G.I. Generation
# 28                 833     Generation X
# 29                 833           Silent
# 30                 833     Generation X
# 31                 833          Boomers
# 32                 833  G.I. Generation
# 33                 833     Generation X
# 34                 833  G.I. Generation
# 35                 833     Generation X
# 36                 251          Boomers
# 37                 251     Generation X
# 38                 251           Silent
# 39                 251          Boomers
# 40                 251     Generation X
# 41                 251          Boomers
# 42                 251          Boomers
# 43                 251           Silent
# 44                 251       Millenials
# 45                 251  G.I. Generation
# 46                 251       Millenials
# 47                 251  G.I. Generation
# 48                 437     Generation X
# 49                 437           Silent

# %%
dfdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# # Estadisticos globales del data frame

# %%
dfdata['age'].unique()
# Out:
# array(['15-24 years', '35-54 years', '75+ years', '25-34 years',
#        '55-74 years', '5-14 years'], dtype=object)

# %%
dfdata.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
len(dfdata['country'].unique())
# Out:
# 101

# %%
dfdata['country'].unique()
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Republic of Korea', 'Romania', 'Russian Federation',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and Grenadines', 'San Marino', 'Serbia',
#        'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Suriname', 'Sweden', 'Switzerland',
#        'Thailand', 'Trinidad and Tobago', 'Turkey', 'Turkmenistan',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan'], dtype=object)

# %%
len(dfdata['country'].unique())
# Out:
# 101

# %%
dfdata.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# max        0.944000       126352.000000

# %% [markdown]
# Analisis Exploratorio

# %% [markdown]
# # Cuenta de aparición de los paises en el data frame
# # Se agrupan los datos por la columna country
# # Se toma la columna year para tener una de referencia (Podría haber sido cualquier otra)
# # Se saca la cuenta de los datos con .count()
# # Se ordenan los datos de manera descendente con .sort_values(ascending=False)

# %%
dfdata.groupby(['country'])['year'].count().sort_values(ascending=False)
# Out:
# country
# Mauritius                 382
# Austria                   382
# Netherlands               382
# Iceland                   382
# Brazil                    372
#                          ...
# Bosnia and Herzegovina     24
# Cabo Verde                 12
# Dominica                   12
# Macau                      12
# Mongolia                   10
# Name: year, Length: 101, dtype: int64

# %% [markdown]
# Número de suicidios promedio de cada país por cada año

# %%
dfdata.pivot_table('suicides_no', index=('country'), columns=('year'), aggfunc=('mean'), margins=True).fillna(0)
# Out:
# year                        1985         1986         1987         1988  \
# country
# Albania                 0.000000     0.000000     6.083333     5.250000
# Antigua and Barbuda     0.000000     0.000000     0.000000     0.000000
# Argentina             165.666667   190.333333   190.500000   196.166667
# Armenia                 0.000000     0.000000     0.000000     0.000000
# Aruba                   0.000000     0.000000     0.000000     0.000000
# ...                          ...          ...          ...          ...
# United Kingdom        425.416667   403.250000   382.833333   414.250000
# United States        2453.833333  2574.333333  2565.250000  2532.333333
# Uruguay                23.916667    21.833333    21.500000    22.333333
# Uzbekistan              0.000000     0.000000     0.000000     0.000000
# All                   201.498264   209.496528   195.743827   205.826531
#
# year                        1989         1990         1991         1992  \
# country
# Albania                 5.666667     0.000000     0.000000     3.916667
# Antigua and Barbuda     0.000000     0.083333     0.000000     0.000000
# Argentina             187.250000   178.333333   162.583333   182.000000
# Armenia                 0.000000     7.750000     6.666667     6.916667
# Aruba                   0.000000     0.000000     0.000000     0.000000
# ...                          ...          ...          ...          ...
# United Kingdom        363.416667   386.916667   378.916667   385.666667
# United States        2518.166667  2574.583333  2565.833333  2539.250000
# Uruguay                28.666667    26.250000     0.000000     0.000000
# Uzbekistan              0.000000   121.583333   116.083333   112.000000
# All                   256.801282   251.772135   257.838542   271.119231
#
# year                        1993         1994  ...         2008         2009  \
# country                                        ...
# Albania                 6.083333     4.166667  ...    13.333333     0.000000
# Antigua and Barbuda     0.083333     0.000000  ...     0.000000     0.000000
# Argentina             185.833333   186.750000  ...   254.916667   240.333333
# Armenia                 8.833333     9.333333  ...     5.250000     4.416667
# Aruba                   0.000000     0.000000  ...     0.333333     0.333333
# ...                          ...          ...  ...          ...          ...
# United Kingdom        371.833333   365.000000  ...   354.916667   353.833333
# United States        2590.333333  2593.583333  ...  3002.500000  3075.000000
# Uruguay                34.833333    33.833333  ...    43.583333    42.583333
# Uzbekistan            112.916667   118.250000  ...     0.000000   116.583333
# All                   284.057692   284.390931  ...   230.830392   227.984082
#
# year                        2010         2011         2012         2013  \
# country
# Albania                 8.000000     0.000000     0.000000     0.000000
# Antigua and Barbuda     0.000000     0.000000     0.000000     0.000000
# Argentina             245.250000   242.666667   270.666667   248.916667
# Armenia                 6.083333     5.583333     6.583333     5.583333
# Aruba                   0.583333     0.750000     0.000000     0.000000
# ...                          ...          ...          ...          ...
# United Kingdom        349.000000   366.083333   370.333333   402.000000
# United States        3196.833333  3292.333333  3383.000000  3428.583333
# Uruguay                45.583333     0.000000    49.916667    45.500000
# Uzbekistan            122.000000   136.666667   152.916667   162.500000
# All                   226.043561   229.151163   236.790123   232.498958
#
# year                        2014         2015      2016          All
# country
# Albania                 0.000000     0.000000   0.00000     7.462121
# Antigua and Barbuda     0.000000     0.083333   0.00000     0.033951
# Argentina             269.250000   256.083333   0.00000   221.018817
# Armenia                 4.833333     6.166667   6.70000     6.392617
# Aruba                   0.000000     0.000000   0.00000     0.601190
# ...                          ...          ...       ...          ...
# United Kingdom        399.000000   409.166667   0.00000   367.755376
# United States        3564.083333  3682.416667   0.00000  2779.604839
# Uruguay                49.250000    52.500000   0.00000    39.101190
# Uzbekistan            174.583333     0.000000   0.00000   131.829545
# All                   238.230769   273.709677  97.51875   242.574407
#
# [102 rows x 33 columns]

# %% [markdown]
# Cantidad de registros por sexo y por rango etario

# %%
dfdata['sex'].value_counts()
# Out:
# male      13910
# female    13910
# Name: sex, dtype: int64

# %%
dfdata['age'].value_counts()
# Out:
# 15-24 years    4642
# 35-54 years    4642
# 75+ years      4642
# 25-34 years    4642
# 55-74 years    4642
# 5-14 years     4610
# Name: age, dtype: int64

# %%
# Verificamos que valores existen en la columnas 'HDI for year'
dfdata['HDI for year'].unique()
# Out:
# array([  nan, 0.619, 0.656, 0.695, 0.722, 0.781, 0.783, 0.694, 0.705,
#        0.731, 0.762, 0.775, 0.811, 0.818, 0.831, 0.833, 0.836, 0.632,
#        0.605, 0.648, 0.721, 0.723, 0.728, 0.733, 0.865, 0.882, 0.898,
#        0.927, 0.93 , 0.932, 0.933, 0.935, 0.764, 0.794, 0.815, 0.853,
#        0.879, 0.881, 0.884, 0.885, 0.609, 0.64 , 0.778, 0.78 , 0.774,
#        0.786, 0.727, 0.816, 0.819, 0.817, 0.821, 0.824, 0.7  , 0.716,
#        0.753, 0.765, 0.793, 0.785, 0.683, 0.796, 0.798, 0.806, 0.851,
#        0.874, 0.866, 0.883, 0.886, 0.889, 0.888, 0.89 , 0.644, 0.664,
#        0.701, 0.71 , 0.711, 0.715, 0.724, 0.576, 0.608, 0.702, 0.737,
#        0.742, 0.746, 0.752, 0.755, 0.686, 0.696, 0.713, 0.749, 0.773,
#        0.779, 0.782, 0.827, 0.849, 0.861, 0.867, 0.892, 0.903, 0.909,
#        0.91 , 0.912, 0.654, 0.699, 0.788, 0.814, 0.83 , 0.832, 0.573,
#        0.596, 0.629, 0.679, 0.706, 0.718, 0.72 , 0.623, 0.652, 0.682,
#        0.704, 0.75 , 0.756, 0.761, 0.766, 0.807, 0.653, 0.685, 0.73 ,
#        0.776, 0.772, 0.768, 0.769, 0.8  , 0.848, 0.852, 0.85 , 0.847,
#        0.863, 0.868, 0.87 , 0.862, 0.902, 0.908, 0.92 , 0.921, 0.923,
#        0.631, 0.645, 0.665, 0.674, 0.698, 0.717, 0.732, 0.522, 0.566,
#        0.603, 0.638, 0.658, 0.662, 0.666, 0.719, 0.838, 0.855, 0.859,
#        0.857, 0.869, 0.878, 0.741, 0.825, 0.887, 0.672, 0.735, 0.74 ,
#        0.747, 0.754, 0.801, 0.906, 0.911, 0.915, 0.916, 0.759, 0.799,
#        0.864, 0.739, 0.483, 0.513, 0.552, 0.611, 0.617, 0.624, 0.626,
#        0.627, 0.542, 0.581, 0.618, 0.63 , 0.634, 0.802, 0.823, 0.828,
#        0.826, 0.896, 0.897, 0.899, 0.77 , 0.803, 0.895, 0.893, 0.894,
#        0.738, 0.829, 0.856, 0.873, 0.872, 0.65 , 0.671, 0.729, 0.791,
#        0.891, 0.69 , 0.804, 0.795, 0.809, 0.812, 0.615, 0.562, 0.593,
#        0.614, 0.639, 0.655, 0.67 , 0.813, 0.837, 0.839, 0.805, 0.88 ,
#        0.822, 0.575, 0.647, 0.777, 0.748, 0.877, 0.919, 0.922, 0.82 ,
#        0.905, 0.907, 0.625, 0.628, 0.917, 0.931, 0.94 , 0.941, 0.942,
#        0.944, 0.714, 0.564, 0.579, 0.604, 0.646, 0.668, 0.669, 0.677,
#        0.84 , 0.843, 0.676, 0.844, 0.841, 0.703, 0.751, 0.691, 0.697,
#        0.757, 0.771, 0.736, 0.743, 0.767, 0.763, 0.876, 0.613, 0.643,
#        0.651, 0.659, 0.663, 0.725, 0.845, 0.597, 0.692, 0.707, 0.709,
#        0.901, 0.904, 0.846, 0.924, 0.925, 0.928, 0.539, 0.572, 0.684,
#        0.726, 0.673, 0.688, 0.913, 0.667, 0.79 , 0.594, 0.661, 0.675])

# %%
len(dfdata['HDI for year'].unique())
# Out:
# 306

# %%
# Verificamos que generaciones aparecen en el estudio
dfdata['generation'].unique()
# Out:
# array(['Generation X', 'Silent', 'G.I. Generation', 'Boomers',
#        'Millenials', 'Generation Z'], dtype=object)

# %%
# Vemos la cantidad de muertes en colombia por cada año
dfdata[dfdata['country']=='Colombia'][['year','country']].groupby('year').count()
# Out:
#       country
# year
# 1985       12
# 1986       12
# 1987       12
# 1988       12
# 1989       12
# 1990       12
# 1991       12
# 1992       12
# 1993       12
# 1994       12
# 1995       12
# 1996       12
# 1997       12
# 1998       12
# 1999       12
# 2000       12
# 2001       12
# 2002       12
# 2003       12
# 2004       12
# 2005       12
# 2006       12
# 2007       12
# 2008       12
# 2009       12
# 2010       12
# 2011       12
# 2012       12
# 2013       12
# 2014       12
# 2015       12

# %% [markdown]
# Promedio de muertes anuales por pais

# %%
dfdata[['country','suicides_no']].groupby('country').mean().sort_values(by='suicides_no', ascending=False)
# Out:
#                               suicides_no
# country
# Russian Federation            3733.771605
# United States                 2779.604839
# Japan                         2169.091398
# Ukraine                        952.232143
# Germany                        933.532051
# France                         914.241667
# Republic of Korea              703.575269
# Brazil                         609.174731
# Poland                         482.979167
# Sri Lanka                      421.522727
# United Kingdom                 367.755376
# Italy                          355.000000
# Thailand                       331.266467
# Kazakhstan                     325.467949
# Canada                         309.083333
# Mexico                         298.760753
# Spain                          269.360215
# Hungary                        238.358065
# Belarus                        237.666667
# Argentina                      221.018817
# Romania                        217.895210
# Australia                      194.752778
# Belgium                        168.712366
# Cuba                           143.812500
# Colombia                       142.688172
# Czech Republic                 135.673913
# Netherlands                    133.070681
# Uzbekistan                     131.829545
# Austria                        131.081152
# Turkey                         120.607143
# Philippines                    118.500000
# Serbia                         111.939815
# Chile                          109.932796
# Lithuania                      107.019084
# Sweden                         105.572626
# Switzerland                    104.035714
# Bulgaria                       101.077778
# Finland                         96.772989
# Portugal                        74.262346
# Croatia                         70.339695
# Denmark                         57.943182
# Ecuador                         55.537634
# Slovakia                        50.897727
# Latvia                          50.674603
# Norway                          47.200000
# Mongolia                        42.300000
# Slovenia                        42.123016
# Kyrgyzstan                      41.955128
# New Zealand                     41.330460
# El Salvador                     40.565972
# Uruguay                         39.101190
# Ireland                         34.927778
# Greece                          33.247312
# South Africa                    30.504167
# Israel                          30.360215
# Nicaragua                       27.958333
# Estonia                         27.912698
# Singapore                       27.120968
# Turkmenistan                    24.781609
# Puerto Rico                     24.309140
# Guatemala                       22.636111
# Costa Rica                      18.866667
# Paraguay                        14.762346
# Bosnia and Herzegovina          13.250000
# Trinidad and Tobago             12.466049
# Georgia                         12.212121
# Panama                          11.610000
# Guyana                          11.420000
# Mauritius                       10.193717
# United Arab Emirates             8.638889
# Azerbaijan                       8.625000
# Albania                          7.462121
# Suriname                         6.446429
# Armenia                          6.392617
# Luxembourg                       5.263441
# Montenegro                       3.933333
# Cabo Verde                       3.500000
# Qatar                            3.224719
# Kuwait                           3.220000
# Iceland                          2.900524
# Cyprus                           2.314607
# Fiji                             2.303030
# Macau                            2.250000
# Bahrain                          1.837302
# Malta                            1.572581
# Belize                           1.035714
# Oman                             0.916667
# Jamaica                          0.901961
# Saint Lucia                      0.684524
# Aruba                            0.601190
# Barbados                         0.590000
# Seychelles                       0.453704
# Saint Vincent and Grenadines     0.413333
# Kiribati                         0.401515
# Bahamas                          0.336957
# Maldives                         0.166667
# Grenada                          0.122581
# San Marino                       0.111111
# Antigua and Barbuda              0.033951
# Saint Kitts and Nevis            0.000000
# Dominica                         0.000000

# %%
# Se crea un 'figure' y se indica que tendra un ancho de 8 y un alto de 8
plt.figure(1, figsize=(8,8))
# Se obtiene la cuenta de los datos agrupados por año y se grafican
dfdata.groupby(['year']).count()['country'].plot(kind='bar')
# Agregamos un título al gráfico
plt.title('Diagrama de barras de los suicidios anuales')
plt.show()

# %% [markdown]
# Suicidios totales por pais en comparación al promedio de muertes

# %%
plt.figure(1, figsize=(8,8))
dfdata.groupby(['year']).count()['country'].plot(kind='bar')
plt.title('Diagrama de barras de los suicidios anuales')
plt.xlabel('Pais')
plt.ylabel('Total de suicidios')
# Se crea una línea recta que indica el promedio de muertes
plt.hlines(dfdata['suicides_no'].sum() / dfdata.shape[0], -5, 2020, color='red')
plt.show()
plt.show()

# %%
dfdata['decade']=(dfdata['year']//10)*10
dfdata['decade']= dfdata['decade'].astype(str) + 's'
dfdata.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation decade
# 0                 796     Generation X  1980s
# 1                 796           Silent  1980s
# 2                 796     Generation X  1980s
# 3                 796  G.I. Generation  1980s
# 4                 796          Boomers  1980s

# %%
dfdata.groupby('decade').count()
# Out:
#         country   year    sex    age  suicides_no  population  \
# decade
# 1980s      3012   3012   3012   3012         3012        3012
# 1990s      8640   8640   8640   8640         8640        8640
# 2000s     10308  10308  10308  10308        10308       10308
# 2010s      5860   5860   5860   5860         5860        5860
#
#         suicides/100k pop  country-year  HDI for year   gdp_for_year ($)   \
# decade
# 1980s                3012          3012           444                3012
# 1990s                8640          8640          1356                8640
# 2000s               10308         10308          1824               10308
# 2010s                5860          5860          4740                5860
#
#         gdp_per_capita ($)  generation
# decade
# 1980s                 3012        3012
# 1990s                 8640        8640
# 2000s                10308       10308
# 2010s                 5860        5860

# %%
plt.figure(1, figsize=(8,8))
dfdata.groupby('decade')['decade'].count().plot(kind='bar')
plt.title('suicidios por decadas')
# Iteramos la cantidad de décadas que existan
for i in range(len(dfdata['decade'].unique().tolist())):
    # Obtenemos el valor de Y, el que será la cantidad de datos que tiene el intervalo
    y = dfdata.groupby('decade').count()['country'].iloc[i]
    # Agregamos como texto la cantidad de datos del intervalo
    # en las coordenadas x=posición del gráfico - 0.2, y=La cantidad de datos en la decada / 2
    plt.text(i-0.2, y//2, y, color='black', fontsize=13)

plt.show()

# %% [markdown]
# bosnia, cabo verde, republica dominicana, macau y mongolia son los paises con menor tasa de suicidios
# islandia, austria, mauritius y netherlands son los paises con mayor tasa de suicidio
# En el mundo hay un promedio de 243 muertes anuales aproximadamente
# Al parecer los suicidios han ido disminuyendo en la última década a nivel mundial
# La generación z (Aquellos nacidos después de 1995) al parecer tienen menos suicidios
# Al ver Chile, este aparenta tener una tasa de suicidio que sigue una distribución uniforme
# Rusia, estados unidos y japón son los paises con mayor tasa de suicidios promedio, superando a los demas paises en mas de 1.000 suicidios anuales
# La decada del 2000 ha sido la que mas suicidios ha presentado según el estudio, por ocntraparte, la de 1980 es la que menos suicidios presento
